# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np
import os
# import pandas as pd
# Out:
# 2023-06-28 10:38:37.192807: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Dataset preparation

# %% [markdown]
# ### Set parameters

# %%
batch_size = 32
img_height = 184
img_width = 216
img_size = (img_height, img_width)
img_shape = img_size + (3,)

# %% [markdown]
# ### Load dataset

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_path = "../dataset_2/training"
val_path = "../dataset_2/validation"

with tf.device("CPU"):
    train_ds = image_dataset_from_directory(train_path,
                                        seed = 123,
                                        image_size = img_size,
                                        batch_size = batch_size)
    
    val_ds = image_dataset_from_directory(val_path,
                                      seed = 456,
                                      image_size = img_size,
                                      batch_size = batch_size)
# Out:
# 2023-06-28 10:38:39.327554: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-28 10:38:39.893765: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1637] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7910 MB memory:  -> device: 0, name: A100-SXM4-40GB MIG 2g.10gb, pci bus id: 0000:90:00.0, compute capability: 8.0
# Found 11289 files belonging to 3 classes.
# Found 2823 files belonging to 3 classes.

# %%
class_names = train_ds.class_names
num_classes = len(class_names)

print(class_names)
# Out:
# ['bipolar_disorder', 'healthy_controls', 'schizophrenia']

# %% [markdown]
# ### Test set

# %%
with tf.device("CPU"):
    AUTOTUNE = tf.data.AUTOTUNE
    val_batches = tf.data.experimental.cardinality(val_ds)
    test_dataset = val_ds.take(val_batches // 2)
    validation_dataset = val_ds.skip(val_batches // 2)
    
    # Buffered prefetching
    train_dataset = train_ds.prefetch(buffer_size = AUTOTUNE)
    validation_dataset = validation_dataset.prefetch(buffer_size = AUTOTUNE)
    test_dataset = test_dataset.prefetch(buffer_size = AUTOTUNE)

# %%
print(len(validation_dataset))
print(len(test_dataset))
# Out:
# 45
# 44

# %% [markdown]
# ## Model building

# %%
def lenet(dropout_num):
    model = Sequential([
    Conv2D(8, (3, 3), activation='relu', input_shape=img_shape),
    Dropout(dropout_num),
    MaxPooling2D((2, 2)),
        
    Conv2D(16, (3, 3), activation='relu'),
    Dropout(dropout_num),
    MaxPooling2D((2, 2)),
    MaxPooling2D((2, 2)),   
        
    Flatten(),
    Dense(32, activation='relu'),
    Dense(32, activation='relu'),
#     Dropout(dropout_num),
    Dense(3, activation='softmax')
])
    return model

# %%
with tf.device("GPU"):
    model = lenet(0.2)

    # compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 1e-3),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = False),
                  metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 182, 214, 8)       224
#
#  dropout (Dropout)           (None, 182, 214, 8)       0
#
#  max_pooling2d (MaxPooling2D  (None, 91, 107, 8)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 89, 105, 16)       1168
#
#  dropout_1 (Dropout)         (None, 89, 105, 16)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 44, 52, 16)       0
#  2D)
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 26, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 9152)              0
#
#  dense (Dense)               (None, 32)                292896
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 295,443
# Trainable params: 295,443
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model training

# %%
# Callback function
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy')>0.95):
            print("\nReached 95% accuracy, cancelling training")
            self.model.stop_training = True
            
callbacks = myCallback()
save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
checkpoints_cb = tf.keras.callbacks.ModelCheckpoint('./cnn1_checkpoints', options=save_locally)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=4)

# %%
EPOCH = 150

history = model.fit(
            train_dataset,
            validation_data = validation_dataset,
            epochs = EPOCH,
            batch_size = 32,
            callbacks=[callbacks])
# Out:
# Epoch 1/150
# 2023-06-28 10:38:50.957702: I tensorflow/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-06-28 10:38:51.695428: I tensorflow/stream_executor/cuda/cuda_blas.cc:1633] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 353/353 [==============================] - 8s 16ms/step - loss: 2.3182 - accuracy: 0.3929 - val_loss: 1.1026 - val_accuracy: 0.3435
# Epoch 2/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.9895 - accuracy: 0.4820 - val_loss: 1.1258 - val_accuracy: 0.3449
# Epoch 3/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.9112 - accuracy: 0.5496 - val_loss: 1.1695 - val_accuracy: 0.3873
# Epoch 4/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.8309 - accuracy: 0.6000 - val_loss: 1.2510 - val_accuracy: 0.3675
# Epoch 5/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.7553 - accuracy: 0.6476 - val_loss: 1.3382 - val_accuracy: 0.3633
# Epoch 6/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.6811 - accuracy: 0.6962 - val_loss: 1.4010 - val_accuracy: 0.3739
# Epoch 7/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.6173 - accuracy: 0.7410 - val_loss: 1.5065 - val_accuracy: 0.3569
# Epoch 8/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.5444 - accuracy: 0.7774 - val_loss: 1.6508 - val_accuracy: 0.3576
# Epoch 9/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.4931 - accuracy: 0.8008 - val_loss: 1.6415 - val_accuracy: 0.3823
# Epoch 10/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.4382 - accuracy: 0.8256 - val_loss: 1.6734 - val_accuracy: 0.3576
# Epoch 11/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.3863 - accuracy: 0.8496 - val_loss: 2.0285 - val_accuracy: 0.3710
# Epoch 12/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.3605 - accuracy: 0.8633 - val_loss: 1.8306 - val_accuracy: 0.3724
# Epoch 13/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.3253 - accuracy: 0.8769 - val_loss: 1.9689 - val_accuracy: 0.4000
# Epoch 14/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.3206 - accuracy: 0.8773 - val_loss: 2.0085 - val_accuracy: 0.3993
# Epoch 15/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.2739 - accuracy: 0.8975 - val_loss: 2.0186 - val_accuracy: 0.3823
# Epoch 16/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.2582 - accuracy: 0.9065 - val_loss: 2.2894 - val_accuracy: 0.3845
# Epoch 17/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.2566 - accuracy: 0.9081 - val_loss: 2.1344 - val_accuracy: 0.3830
# Epoch 18/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.2295 - accuracy: 0.9155 - val_loss: 2.3387 - val_accuracy: 0.3781
# Epoch 19/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.2209 - accuracy: 0.9170 - val_loss: 2.5128 - val_accuracy: 0.3717
# Epoch 20/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.2158 - accuracy: 0.9222 - val_loss: 2.3089 - val_accuracy: 0.3703
# Epoch 21/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.1998 - accuracy: 0.9275 - val_loss: 2.3242 - val_accuracy: 0.3845
# Epoch 22/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.1750 - accuracy: 0.9364 - val_loss: 2.4096 - val_accuracy: 0.3724
# Epoch 23/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.1719 - accuracy: 0.9397 - val_loss: 2.3863 - val_accuracy: 0.4049
# Epoch 24/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.1724 - accuracy: 0.9370 - val_loss: 2.5437 - val_accuracy: 0.3774
# Epoch 25/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.1818 - accuracy: 0.9331 - val_loss: 2.4919 - val_accuracy: 0.3845
# Epoch 26/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.1586 - accuracy: 0.9457 - val_loss: 2.5968 - val_accuracy: 0.3731
# Epoch 27/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.1481 - accuracy: 0.9466 - val_loss: 2.6836 - val_accuracy: 0.3873
# Epoch 28/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.1579 - accuracy: 0.9416 - val_loss: 2.5755 - val_accuracy: 0.3590
# Epoch 29/150
# 353/353 [==============================] - 5s 15ms/step - loss: 0.1400 - accuracy: 0.9488 - val_loss: 2.6979 - val_accuracy: 0.3816
# Epoch 30/150
# 349/353 [============================>.] - ETA: 0s - loss: 0.1281 - accuracy: 0.9540
# Reached 95% accuracy, cancelling training
# 353/353 [==============================] - 5s 15ms/step - loss: 0.1282 - accuracy: 0.9539 - val_loss: 2.8922 - val_accuracy: 0.3788

# %% [markdown]
# ### Training evaluation

# %%
plt.figure(figsize=(8, 8))

# training and validation accuracy
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
# plt.ylim([min(plt.ylim()),1])
plt.title('Accuracy', size=15, fontweight='bold')

# training and validation loss
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.xlabel('Epoch')
# plt.ylim([0,1.0])
plt.title('Loss', size=15, fontweight='bold')

plt.subplots_adjust(hspace=0.3)
plt.show()

# %% [markdown]
# ## Testing

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score
import seaborn as sns

# %%
result = model.evaluate(test_dataset)
dict(zip(model.metrics_names, result))
# Out:
# 44/44 [==============================] - 0s 7ms/step - loss: 2.7639 - accuracy: 0.3786
# {'loss': 2.76389741897583, 'accuracy': 0.3785511255264282}

# %%
predicted = []  # predicted labels
true = []  # true labels

for image_batch, label_batch in test_dataset:  
    true.append(label_batch)
    prediction = model.predict(image_batch, verbose=0)
    predicted.append(np.argmax(prediction, axis=-1))

# convert labels into tensors
true_labels = tf.concat([item for item in true], axis=0)
predicted_labels = tf.concat([item for item in predicted], axis=0)

cf_matrix = confusion_matrix(true_labels, predicted_labels, normalize='true')

# plot confusion  matrix
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
sns.heatmap(cf_matrix, 
            annot=True)
ax.xaxis.set_ticklabels(class_names)
ax.yaxis.set_ticklabels(class_names)
plt.xlabel('Predicted Label', labelpad=15, size=12, fontweight='bold')
plt.ylabel('True Label', labelpad=15, size=12, fontweight='bold')
plt.title('Confusion Matrix', size=15, fontweight='bold')
plt.savefig('./lenet2_cm.png')
plt.show()

# %%
precision = precision_score(true_labels, predicted_labels, average='weighted')
sensitivity = recall_score(true_labels, predicted_labels, average='weighted')
specificity = []
for i in range(num_classes):
    true_negatives = np.sum(np.delete(np.delete(cf_matrix, i, axis=0), i, axis=1))
    false_positives = np.sum(cf_matrix[:, i]) - cf_matrix[i, i]
    specificity.append(true_negatives / (true_negatives + false_positives))

# Calculate average specificity
average_specificity = np.mean(specificity)

print("Accuracy:", result[1])
print("Precision:", precision)
print("Sensitivity:", sensitivity)
print("Specificity:", average_specificity)
# Out:
# Accuracy: 0.3785511255264282
# Precision: 0.3860882865471582
# Sensitivity: 0.3849431818181818
# Specificity: 0.6921675235331569
